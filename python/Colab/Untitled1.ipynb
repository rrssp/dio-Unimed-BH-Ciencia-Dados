# %%
#Criando uma lista chamada animais
animais = [1,2,3]
animais
# Out:
# [1, 2, 3]

# %%
animais = ["cachorro", "gato", 12345,6.5]
animais
# Out:
# ['cachorro', 'gato', 12345, 6.5]

# %%
#Imprimindo o primeiro elemento da lista
animais[0]
# Out:
# 'cachorro'

# %%
#Imprimindo o 4 elemento da lista
animais[3]
# Out:
# 6.5

# %%
#Substituindo o primeiro elemento da lista
animais[0] = "papagaio"

# %%
animais
# Out:
# ['papagaio', 'gato', 12345, 6.5]

# %%
#Removendo gato da lista
animais.remove("gato")

# %%
animais
# Out:
# ['papagaio', 12345, 6.5]

# %%
len(animais)
# Out:
# 3

# %%
"gato" in animais
# Out:
# False

# %%
6.5 in animais
# Out:
# True

# %%
"papagaio" in animais
# Out:
# True

# %%
animais.append "sapo"
# Out:
#   File "<ipython-input-15-f0e6fd9af8ff>", line 1
#     animais.append "sapo"
#                         ^
# SyntaxError: invalid syntax

# %%
animais[0:1]
# Out:
# ['papagaio']

# %%
"papagaio" in animais
# Out:
# True

# %%
lista = [500,30,300,30,10
         ]

# %%
max(lista)
# Out:
# 500

# %%
min(lista)
# Out:
# 10

# %%
animais.append("leão")

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'leão']

# %%
animais.extend(["Cobra",6])

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'leão', 'Cobra', 6]

# %%
animais.count("cachorro")
# Out:
# 0

# %%
animais.count("leão")
# Out:
# 1

# %%
lista.sort()

# %%
lista
# Out:
# [10, 30, 30, 300, 500]

# %%
#As tuplas usam parêntese com sintaxe
tp = ("Banana", "Maçã", 10, 50)

# %%
tp
# Out:
# ('Banana', 'Maçã', 10, 50)

# %%
#Retornando o primeiro elemento
tp[0]
# Out:
# 'Banana'

# %%
#Diferente das listas as tuplas são imutáveis, o quer dizer não podemos alterar os seus elementos
tp[0] = "Laranja"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-3af9d6eccd03> in <module>
#       1 #Diferente das listas as tuplas são imutáveis, o quer dizer não podemos alterar os seus elementos
# ----> 2 tp[0] = "Laranja"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tp.count("Maçã")
# Out:
# 1

# %%
tp[0:2]
# Out:
# ('Banana', 'Maçã')

# %%
#Para criar um dicionário utilizamos as {}
dc = {"Maça":20, "Banana":10, "Laranja":15, "Uva":5} #Dicionário trabalham com o  conceito chave e valor

# %%
dc
# Out:
# {'Maça': 20, 'Banana': 10, 'Laranja': 15, 'Uva': 5}

# %%
dc["Maça"]
# Out:
# 20

# %%
#Atualizando o valor da maçã
dc["Maça"] = 25
dc
# Out:
# {'Maça': 25, 'Banana': 10, 'Laranja': 15, 'Uva': 5}

# %%
#Retornando todas as chaves do dicionário
dc.keys()
# Out:
# dict_keys(['Maça', 'Banana', 'Laranja', 'Uva'])

# %%
#Retornando todas os valores do dicionário
dc.values()
# Out:
# dict_values([25, 10, 15, 5])

# %%
#Verificando se já existe uma chave no dicionário e caso não exista inserir
dc.setdefault("Limão", 22)
dc
# Out:
# {'Maça': 25, 'Banana': 10, 'Laranja': 15, 'Uva': 5, 'Limão': 22}
